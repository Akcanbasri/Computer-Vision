# %% [markdown]
# ## RESTNET50

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
model = ResNet50(weights='imagenet')

# %%
test_path = "./data/elephent.jpeg"
img = image.load_img(test_path, target_size=(224, 224))

img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = preprocess_input(img)

predicton = model.predict(img)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
predicton = decode_predictions(predicton, top=3)[0]

# %%
predicton
# Out:
# [('n01871265', 'tusker', 0.60337424),
#  ('n02504458', 'African_elephant', 0.33118796),
#  ('n02504013', 'Indian_elephant', 0.06494108)]

# %% [markdown]
# ## VGG 16

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
model = VGG16(weights="imagenet")

# %%
test_path = "./data/elephent.jpeg"
img = image.load_img(test_path, target_size=(224, 224))

img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = preprocess_input(img)

predicton = model.predict(img)
predicton
# Out:
# 1/1 [==============================] - 1s 953ms/step
# array([[4.28839126e-12, 3.71834462e-15, 9.68923529e-15, 4.64678294e-15,
#         1.98387839e-14, 6.11167407e-14, 1.33168445e-14, 5.24325158e-13,
#         8.55173679e-14, 4.67497360e-11, 1.12901964e-15, 1.47291819e-15,
#         5.93911042e-15, 1.48925756e-15, 1.69319294e-14, 1.65031478e-14,
#         2.91177469e-14, 3.54638634e-14, 5.36773249e-14, 2.16104553e-15,
#         1.29453739e-13, 2.25103998e-11, 4.63899709e-12, 1.80548465e-10,
#         8.39565017e-13, 2.91951589e-14, 2.71660492e-14, 5.58074688e-15,
#         2.39928012e-14, 1.90783363e-14, 2.88150952e-14, 7.54693068e-16,
#         8.77204684e-15, 3.23396637e-13, 1.64960211e-12, 3.07067327e-12,
#         1.69673477e-12, 8.27715785e-14, 3.64155524e-14, 1.85742099e-11,
#         7.72391997e-14, 1.16563041e-14, 1.51945579e-12, 2.71205836e-11,
#         4.49474815e-14, 5.34583987e-13, 8.41849580e-14, 1.28253007e-12,
# ...

# %%
predicton = decode_predictions(predicton, top=3)[0]

# %%
predicton
# Out:
# [('n01871265', 'tusker', 0.54496574),
#  ('n02504458', 'African_elephant', 0.41570374),
#  ('n02504013', 'Indian_elephant', 0.03933048)]

# %% [markdown]
# ## VGG19

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
model = VGG19(weights="imagenet")
# Out:
# ...
# 574710816/574710816 [==============================] - 202s 0us/step

# %%
test_path = "./data/elephent.jpeg"
img = image.load_img(test_path, target_size=(224, 224))
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)
img = preprocess_input(img)

predicton = model.predict(img)
predicton = decode_predictions(predicton, top=3)[0]
predicton
# Out:
# 1/1 [==============================] - 1s 1s/step
# [('n01871265', 'tusker', 0.53894436),
#  ('n02504458', 'African_elephant', 0.4514874),
#  ('n02504013', 'Indian_elephant', 0.009568065)]

# %% [markdown]
# ### ResNet50: 'tusker', 0.60337424
# ### VGG16: 'tusker', 0.54496574
# ### VGG19: 'tusker', 0.53894436
